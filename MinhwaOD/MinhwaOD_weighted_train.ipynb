# %%
# Cell 1: Google Drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Colab 셀에서 실행
# %%writefile /content/drive/MyDrive/SemioticRAG/MinhwaOD/.gitignore
__pycache__/
*.pt
*.cache
data/images/
data/labels/
runs_minhwa/
artifacts/models/
# Out:
# Overwriting /content/drive/MyDrive/SemioticRAG/MinhwaOD/.gitignore

# %%
# 작업 디렉토리로 이동
# %cd /content/drive/MyDrive/SemioticRAG/MinhwaOD

# # 사용자 정보 설정 (Git에 필요한 경우)
# !git config --global user.email "smkim6927@gm.gist.ac.kr"
# !git config --global user.name "Sumin Kim"

# # Git 리포지토리에서 파일 가져오기 (만약 존재하지 않거나 업데이트가 필요한 경우)
# # 디렉토리가 비어있지 않은 경우 git clone 대신 git pull을 사용합니다.
# # 만약 'Minhwa_Object_Detection' 디렉토리가 존재하지 않는다면, 아래 명령어를 사용하세요:
# # !git clone https://github.com/smkim6927/Minhwa_Object_Detection.git .

# # 현재 디렉토리가 이미 Git 리포지토리로 초기화되어 있고, 원격 'origin'이 설정되어 있다고 가정합니다.
# # 원격 'origin'이 설정되어 있지 않다면 아래 주석 처리된 라인을 먼저 실행해야 합니다:
# # !git remote add origin https://github.com/smkim6927/Minhwa_Object_Detection.git

# # 원격 리포지토리에서 최신 변경사항을 가져옵니다.
# !git pull origin main

# %%
# Cell 0: Setup
# !pip install ultralytics wandb

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Setup complete ✅ (12 CPUs, 167.1 GB RAM, 41.7/235.7 GB disk)

# %%
# !unzip -qq "/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images.zip" \
#        -d "/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images"

# !unzip -qq "/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/labels.zip" \
#        -d "/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/labels"

# %%
# %cd /content/drive/MyDrive/SemioticRAG/MinhwaOD
# Out:
# /content/drive/MyDrive/SemioticRAG/MinhwaOD

# %%
import sys
sys.path.append('%cd /content/drive/MyDrive/SemioticRAG/MinhwaOD/src')

# %%
from pathlib import Path

dataset_root = "/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt"
artifacts_dir = str(Path(dataset_root) / "artifacts")

print(dataset_root)
print(artifacts_dir)
# Out:
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/artifacts

# %%
import sys
import os

# Ensure the 'src' directory is in the Python path
src_path = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/src'
if src_path not in sys.path:
    sys.path.append(src_path)

# List of files to fix relative imports in
files_to_fix = ['pipeline.py', 'trainer.py', 'evaluator.py', 'predictor.py', 'exporter.py', 'wandb_utils.py']

for file_name in files_to_fix:
    file_path = os.path.join(src_path, file_name)
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()

        new_content = content

        # Replace relative imports with absolute imports
        new_content = new_content.replace('from .config', 'from config')
        new_content = new_content.replace('from .trainer', 'from trainer')
        new_content = new_content.replace('from .evaluator', 'from evaluator')
        new_content = new_content.replace('from .predictor', 'from predictor')
        new_content = new_content.replace('from .exporter', 'from exporter')

        # Specific fix for SyntaxWarning in pipeline.py
        if file_name == 'pipeline.py':
            # Fix invalid escape sequence in docstring example path
            # Original contains: C:\...\KIDP_yolo_dt\artifacts
            # We escape the backslashes to avoid the SyntaxWarning
            new_content = new_content.replace(r'C:\...\KIDP_yolo_dt\artifacts', r'C:\\...\\KIDP_yolo_dt\\artifacts')

        # Removed the specific fix for wandb_utils.py that caused WandBManager to be unavailable.

        if content != new_content:
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(new_content)
            print(f"Fixed imports and potential syntax warnings in {file_name}")
    except FileNotFoundError:
        print(f"Warning: Could not find {file_name} to patch imports.")
    except Exception as e:
        print(f"Error patching {file_name}: {e}")

from config import TrainConfig
from pipeline import MinHwaDetectPipeline

# %%
# !wandb login
# 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
# Out:
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: ERROR Invalid API key: API key must have 40+ characters, has 37.
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: smkim6927 (gist-infonet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import os

label_base_dir = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/labels'
print(f"Checking directory: {label_base_dir}")
if os.path.exists(label_base_dir):
    subdirs = os.listdir(label_base_dir)
    print("Subdirectories found:", subdirs)

    # Check if there is a nested 'labels' folder
    nested_labels = os.path.join(label_base_dir, 'labels')
    if os.path.exists(nested_labels) and os.path.isdir(nested_labels):
        print("\n[WARNING] Nested 'labels' folder detected!")
        print("Moving files from 'data/labels/labels' to 'data/labels'...")

        # Move command explanation: we will use shell command for efficiency
    else:
        print("\nStructure seems okay (no nested 'labels' folder found directly).")
else:
    print("Label base directory does not exist!")
# Out:
# Checking directory: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/labels
# Subdirectories found: ['train', 'train.cache']
#
# Structure seems okay (no nested 'labels' folder found directly).

# %%
import os
from pathlib import Path
import glob

# 1. Verify Label Existence for the first image
image_path_str = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049372P.JPG.jpg'
expected_label_path = image_path_str.replace('/images/', '/labels/').replace('.jpg', '.txt')

print(f"Image Path: {image_path_str}")
print(f"Expected Label Path: {expected_label_path}")

if os.path.exists(expected_label_path):
    print("[OK] Label file exists at expected path.")
else:
    print("[ERROR] Label file NOT found at expected path.")

    # Check for nested folder hypothesis
    nested_label_path = expected_label_path.replace('/data/labels/', '/data/labels/labels/')
    if os.path.exists(nested_label_path):
        print(f"[FOUND] But it is in a nested folder: {nested_label_path}")
        print("-> We need to move files from 'data/labels/labels' to 'data/labels'.")
    else:
        print("[FAIL] Label file not found even in nested folder.")

# 2. Clear YOLO cache files (important when dataset changes)
cache_pattern = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/**/*.cache'
cache_files = glob.glob(cache_pattern, recursive=True)

if cache_files:
    print(f"\nFound {len(cache_files)} cache files. Deleting them to force re-scan...")
    for cache_file in cache_files:
        try:
            os.remove(cache_file)
            print(f"Deleted: {Path(cache_file).name}")
        except OSError as e:
            print(f"Error deleting {cache_file}: {e}")
else:
    print("\nNo cache files found.")
# Out:
# Image Path: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049372P.JPG.jpg
# Expected Label Path: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/labels/train/0000049372P.JPG.txt
# [ERROR] Label file NOT found at expected path.
# [FAIL] Label file not found even in nested folder.
#
# Found 1 cache files. Deleting them to force re-scan...
# Deleted: train.cache

# %%
import os

img_dir = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train'
label_dir = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/labels/train'

print(f"--- Files in {img_dir} (First 5) ---")
if os.path.exists(img_dir):
    img_files = sorted(os.listdir(img_dir))
    for f in img_files[:5]:
        print(f)
else:
    print("Image directory not found!")

print(f"\n--- Files in {label_dir} (First 5) ---")
if os.path.exists(label_dir):
    label_files = sorted(os.listdir(label_dir))
    for f in label_files[:5]:
        print(f)
else:
    print("Label directory not found!")

# Check for extension match
if img_files and label_files:
    test_img = img_files[0]
    # Logic: YOLO replaces the last extension.
    # If file is 'a.JPG.jpg', it looks for 'a.JPG.txt'
    expected_label = os.path.splitext(test_img)[0] + '.txt'
    print(f"\n[Test Match]")
    print(f"Image: {test_img}")
    print(f"Expected Label: {expected_label}")
    if expected_label in label_files:
        print("-> MATCH FOUND in label directory.")
    else:
        print(f"-> MATCH NOT FOUND. (Closest might be: {label_files[0]}?)")
# Out:
# --- Files in /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train (First 5) ---
# 0000046116P.JPG.jpg
# 0000049110P.JPG.jpg
# 0000049111P.JPG.jpg
# 0000049112P.JPG.jpg
# 0000049114P.JPG.jpg
#
# --- Files in /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/labels/train (First 5) ---
# 0000046116P.JPG.txt
# 0000049110P.JPG.txt
# 0000049111P.JPG.txt
# 0000049112P.JPG.txt
# 0000049114P.JPG.txt
#
# [Test Match]
# Image: 0000046116P.JPG.jpg
# Expected Label: 0000046116P.JPG.txt
# -> MATCH FOUND in label directory.

# %%
import yaml
from pathlib import Path
import os

base_path = Path('/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt')
yaml_path = base_path / 'data_ko_8020.yaml'
train_txt_path = base_path / 'train80.txt'

print(f"--- Inspecting {yaml_path.name} ---")
if yaml_path.exists():
    with open(yaml_path, 'r') as f:
        print(f.read())
else:
    print("YAML file not found!")

print(f"\n--- Inspecting first 5 lines of {train_txt_path.name} ---")
if train_txt_path.exists():
    with open(train_txt_path, 'r') as f:
        lines = f.readlines()
        for line in lines[:5]:
            print(line.strip())

    # Check if first image exists
    if lines:
        first_img_path = lines[0].strip()
        if os.path.exists(first_img_path):
            print(f"\n[OK] First image found at: {first_img_path}")
        else:
            print(f"\n[ERROR] First image NOT found at: {first_img_path}")
else:
    print("Train txt file not found!")
# Out:
# --- Inspecting data_ko_8020.yaml ---
# names:
#   0: 범
#   1: 까치
#   2: 용
#   3: 소나무
#   4: 기러기
#   5: 학
#   6: 영지
#   7: 봉황
#   8: 오동나무
#   9: 해
#   10: 바다
#   11: 바위
#   12: 괴석
#   13: 구름
#   14: 꿩
#   15: 동백
#   16: 모란
#   17: 목련
#   18: 매화
#   19: 꽃봉오리
#   20: 닭
#   21: 병아리
#   22: 석류
#   23: 복숭아
#   24: 나비
#   25: 토끼
#   26: 소
#   27: 거북
#   28: 게
#   29: 오징어
#   30: 고양이
#   31: 오리
#   32: 화병
#   33: 화분
#   34: 버드나무
#   35: 정자
#   36: 사슴
#   37: 산
#   38: 물줄기
#   39: 갈대
#   40: 올챙이
#   41: 잉어
#   42: 쏘가리
#   43: 숭어
#   44: 메기
#   45: 붕어
#   46: 연꽃
#   47: 연잎
#   48: 연밥
#   49: 잠자리
#   50: 복숭아꽃
#   51: 석류꽃
#   52: 파랑새
#   53: 팔가조
#   54: 백로
#   55: 원앙
#   56: 제비
#   57: 앵무새
#   58: 물총새
#   59: 국화
#   60: 공작
#   61: 계수나무
#   62: 대나무
#   63: 난초
#   64: 방아깨비
#   65: 아기새
#   66: 송사리
#   67: 참새
#   68: 까마귀
#   69: 복숭아나무
#   70: 매화나무
#   71: 달
#   72: 단풍나무
#   73: 호피
#   74: 개
#   75: 여의주
#   76: 부엉이
#   77: 비둘기
#   78: 석류나무
#   79: 목련나무
#   80: 방울
#   81: 술
#   82: 해태
#   83: 이름 모를 새
#   84: 이름 모를 꽃
#   85: 서기
#   86: 파초
#   87: 말
#   88: 다리
#   89: 배
#   90: 집
#   91: 사람
#   92: 호랑이
#   93: 동충하초
#   94: 영지버섯
#   95: 책
#   96: 기린
#   97: 해오라기
#   98: 폭포
#   99: 작약
#   100: 곰
#   101: 노루
#   102: 황새
#   103: 개구리
#   104: 붓
#   105: 두루마리지
#   106: 금계
#   107: 벚꽃
#   108: 불로초
#   109: 가릉빈가
#   110: 억새
#   111: 도장
#   112: 벼루
#   113: 먹
#   114: 금조
#   115: 수국
#   116: 양귀비
#   117: 꾀꼬리
#   118: 박쥐
#   119: 귀뚜라미
#   120: 동박새
#   121: 백합
#   122: 포도나무
#   123: 무궁화
#   124: 여치
#   125: 장미꽃
#   126: 매
#   127: 감나무
#   128: 농어
#   129: 조개
#   130: 새우
#   131: 병어
#   132: 나팔꽃
#   133: 복어
#   134: 선박
#   135: 당나귀
#   136: 암석
#   137: 소라
#   138: 이름 모를 물고기
#   139: 나무
#   140: 벚나무
#   141: 맨드라미
#   142: 배추
#   143: 차조기
#   144: 사마귀
#   145: 벌
#   146: 원숭이
#   147: 상
#   148: 필통
#   149: 지통
#   150: 이름 모를 과일
#   151: 이름 모를 나무
#   152: 장도
#   153: 그릇
#   154: 탑
#   155: 원추리
#   156: 병풍
#   157: 메추라기
#   158: 봉투
#   159: 호리병
#   160: 해당화
#   161: 도라지꽃
#   162: 딱따구리
#   163: 상사화
#   164: 자라
#   165: 나리꽃
#   166: 패랭이꽃
#   167: 향로
#   168: 안경
#   169: 두루미
#   170: 등나무
#   171: 가선화
#   172: 수선화
#   173: 불수감
#   174: 수석
#   175: 산호가지
#   176: 공작깃털
#   177: 향찻잔
#   178: 찻잔
#   179: 이름 모를 곤충
#   180: 자목련
#   181: 물까치
#   182: 박새
#   183: 자목련나무
#   184: 풍뎅이
#   185: 이름 모를 식물
#   186: 가물치
#   187: 매미
#   188: 포도
#   189: 수박
#   190: 귤
#   191: 참외
#   192: 가지
#   193: 감
#   194: 신발
#   195: 깃털
#   196: 초
#   197: 촛대
#   198: 사당
#   199: 고목
#   200: 부채
#   201: 유자나무
#   202: 초롱꽃
#   203: 위패
#   204: 향합
#   205: 술잔
#   206: 벼루집
#   207: 인함
# path: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt
# train: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/train80.txt
# val: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/test20.txt
# test: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/test20.txt
#
#
# --- Inspecting first 5 lines of train80.txt ---
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049116P.JPG.jpg
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049427P.JPG.jpg
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049418P.JPG.jpg
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049223P.JPG.jpg
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049124P.JPG.jpg
#
# [OK] First image found at: /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049116P.JPG.jpg

# %%
import wandb.integration.ultralytics.callback as wandb_callback
import inspect

print("--- Debugging wandb.integration.ultralytics.callback ---")
print(f"Module: {wandb_callback}")

# Check if plot_detection_validation_results exists in the module
if hasattr(wandb_callback, 'plot_detection_validation_results'):
    print("[FOUND] plot_detection_validation_results exists in module.")
else:
    print("[MISSING] plot_detection_validation_results NOT found in module.")
    # List all attributes to see if it has a different name or if we need to look elsewhere
    print("Attributes:", dir(wandb_callback))

# Check if on_val_end exists
if hasattr(wandb_callback, 'on_val_end'):
    print("[FOUND] on_val_end exists.")
else:
    print("[MISSING] on_val_end NOT found.")
# Out:
# wandb: WARNING This integration is tested and supported for ultralytics v8.0.238 and below.
# wandb: WARNING             Please report any issues to https://github.com/wandb/wandb/issues with the tag `yolov8`.
# --- Debugging wandb.integration.ultralytics.callback ---
# Module: <module 'wandb.integration.ultralytics.callback' from '/usr/local/lib/python3.12/dist-packages/wandb/integration/ultralytics/callback.py'>
# [MISSING] plot_detection_validation_results NOT found in module.
# Attributes: ['Callable', 'ClassificationPredictor', 'ClassificationTrainer', 'ClassificationValidator', 'DetectionPredictor', 'DetectionTrainer', 'DetectionValidator', 'PREDICTOR_TYPE', 'PosePredictor', 'PoseTrainer', 'PoseValidator', 'SAMPredictor', 'SegmentationPredictor', 'SegmentationTrainer', 'SegmentationValidator', 'TRAINER_TYPE', 'Union', 'VALIDATOR_TYPE', 'WandBUltralyticsCallback', 'YOLO', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'add_wandb_callback', 'annotations', 'copy', 'datetime', 'pickle', 'telemetry', 'torch', 'tqdm', 'ultralytics', 'version', 'wandb']
# [MISSING] on_val_end NOT found.

# %%
main_py_path = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/main.py'

with open(main_py_path, 'r', encoding='utf-8') as f:
    content = f.read()

# Fix the KeyError by changing the key name to match the actual output
if 'split_summary["created_yaml"]' in content:
    new_content = content.replace('split_summary["created_yaml"]', 'split_summary["yaml_path"]')
    with open(main_py_path, 'w', encoding='utf-8') as f:
        f.write(new_content)
    print("Successfully fixed 'created_yaml' KeyError in main.py")
else:
    print("Target string 'split_summary[\"created_yaml\"]' not found. It might have been fixed already.")
# Out:
# Successfully fixed 'created_yaml' KeyError in main.py

# %%
main_py_path = '/content/drive/MyDrive/SemioticRAG/MinhwaOD/main.py'

with open(main_py_path, 'r', encoding='utf-8') as f:
    content = f.read()

new_content = content
changes_made = False

# Fix created_train_txt -> train_txt
if 'split_summary["created_train_txt"]' in new_content:
    new_content = new_content.replace('split_summary["created_train_txt"]', 'split_summary["train_txt"]')
    print("Fixed 'created_train_txt' -> 'train_txt'")
    changes_made = True

# Fix created_test_txt -> test_txt (preemptive fix)
if 'split_summary["created_test_txt"]' in new_content:
    new_content = new_content.replace('split_summary["created_test_txt"]', 'split_summary["test_txt"]')
    print("Fixed 'created_test_txt' -> 'test_txt'")
    changes_made = True

if changes_made:
    with open(main_py_path, 'w', encoding='utf-8') as f:
        f.write(new_content)
    print("Successfully patched main.py")
else:
    print("No target strings found to fix in main.py")
# Out:
# Fixed 'created_train_txt' -> 'train_txt'
# Successfully patched main.py

# %%
# %cd /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt

# Run the main script again
# !PYTHONPATH=/content/drive/MyDrive/SemioticRAG/MinhwaOD/src python /content/drive/MyDrive/SemioticRAG/MinhwaOD/main.py
# Out:
# /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt
#
# [Before split sanity check]
# {'yaml_path': '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data_ko.yaml'}
#
# [Split summary]
# {'yaml_path': '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data_ko_8020.yaml',
#  'train_txt': '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/train80.txt',
#  'test_txt': '/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/test20.txt',
#  'total_images': 279,
#  'train_ratio': 0.8,
#  'train_count': 223,
#  'test_count': 56}
#
# [Weighted Sampling Report] (핵심 요약)
# - original images: 223
# - expanded samples: 336  (avg_rep_all=1.51, max_rep=3)
# - rare percentile: bottom 10% classes  (rare_class_count=14)
# - rare-image ratio (orig): 4.93%
# - rare-image ratio (weighted): 9.52%
# - rare ratio multiplier: 1.93x
# - avg rep (rare images): 2.91
# - avg rep (non-rare images): 1.43
#
# [Top rare rep samples] (희소 클래스 포함 이미지 중 rep 높은 샘플)
#   - rep=3  img=data/images/train/0000049427P.JPG.jpg
#   - rep=3  img=data/images/train/0000049223P.JPG.jpg
#   - rep=3  img=data/images/train/0000049261P.JPG.jpg
#   - rep=3  img=data/images/train/0000049293P.JPG.jpg
#   - rep=3  img=data/images/train/0000049181P.JPG.jpg
#   - rep=3  img=data/images/train/0000052875P.JPG.jpg
#   - rep=3  img=data/images/train/0000049218P.JPG.jpg
#   - rep=3  img=data/images/train/0000049156P.JPG.jpg
#   - rep=3  img=data/images/train/0000049416P.JPG.jpg
#   - rep=3  img=data/images/train/0000049114P.JPG.jpg
#
# [Rarest classes topN] (이미지 단위 빈도 하위 클래스)
#   - class_id=176  img_freq=1
#   - class_id=55  img_freq=1
#   - class_id=80  img_freq=1
#   - class_id=74  img_freq=1
#   - class_id=81  img_freq=1
#   - class_id=186  img_freq=1
#   - class_id=73  img_freq=1
#   - class_id=184  img_freq=1
#   - class_id=86  img_freq=1
#   - class_id=51  img_freq=1
#   - class_id=179  img_freq=1
#   - class_id=183  img_freq=1
#   - class_id=193  img_freq=1
#   - class_id=17  img_freq=1
#   - class_id=19  img_freq=1
#   - class_id=68  img_freq=1
#   - class_id=154  img_freq=1
#   - class_id=65  img_freq=1
#   - class_id=159  img_freq=1
#   - class_id=21  img_freq=1
#
# [YAML patched] /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data_ko_8020_weighted.yaml
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: smkim6927 (gist-infonet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run moxdmgvc (0.5s)
# wandb: ⣯ setting up run moxdmgvc (0.5s)
# wandb: ⣟ setting up run moxdmgvc (0.5s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/wandb/run-20260225_135448-moxdmgvc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run colab_train_img1080_weighted
# wandb: ⭐️ View project at https://wandb.ai/gist-infonet/minhwa-od
# wandb: 🚀 View run at https://wandb.ai/gist-infonet/minhwa-od/runs/moxdmgvc
#
# [Train] start
# wandb: WARNING This integration is tested and supported for ultralytics v8.0.238 and below.
# wandb: WARNING             Please report any issues to https://github.com/wandb/wandb/issues with the tag `yolov8`.
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data_ko_8020_weighted.yaml, degrees=5.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1080, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26x.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26_minhwa_detect_8020_img1080_wt, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/runs_minhwa, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/runs_minhwa/yolo26_minhwa_detect_8020_img1080_wt, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=777, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.Unicode.ttf to '/root/.config/Ultralytics/Arial.Unicode.ttf': 100% ━━━━━━━━━━━━ 22.2MB 82.7MB/s 0.3s
# Overriding model.yaml nc=80 with nc=208
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5, 3, True]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   4436736  ultralytics.nn.modules.block.C3k2            [1536, 768, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   6736632  ultralytics.nn.modules.head.Detect           [208, 1, True, [384, 768, 768]]
# YOLO26x summary: 392 layers, 59,289,048 parameters, 59,289,048 gradients, 211.2 GFLOPs
#
# Transferred 1080/1092 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[1080] must be multiple of max stride 32, updating to [1088]
# train: Fast image access ✅ (ping: 0.4±0.0 ms, read: 0.2±0.1 MB/s, size: 125.7 KB)
# train: Scanning data/labels/train... 266 images, 70 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━
#                     파초          1          1          1          0          0          0
#                      말          3          3          0          0          0          0
#                     다리          4          5      0.495        0.2      0.226      0.139
#                      집          5         29      0.453      0.241      0.252      0.154
#                     사람          4          8          1      0.478      0.708      0.459
#                      책          1          4      0.717        0.5      0.558      0.345
#                     폭포          2          2          0          0          0          0
#                   포도나무          1          1          0          0          0          0
#                     새우          1          1          1          0          0          0
#                     선박          1         17          1      0.232      0.721      0.558
#                     암석          6         16      0.232        0.5      0.304      0.122
#                   맨드라미          1          2          0          0          0          0
#               이름 모를 나무          5         28      0.345      0.429      0.356      0.229
#                     그릇          1          1      0.524          1      0.995      0.821
#                    불수감          1          1          0          0          0          0
#                    물까치          1          2          0          0     0.0399     0.0399
#               이름 모를 식물          1          1          0          0          0          0
#                     포도          1          3          1          0          0          0
#                     고목          1          1          0          0     0.0765     0.0459
# Speed: 4.2ms preprocess, 18.2ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/runs/detect/val3
# {'results_dict': {'metrics/precision(B)': 0.5088061376781912,
#                   'metrics/recall(B)': 0.2219121255172951,
#                   'metrics/mAP50(B)': 0.28773948831996443,
#                   'metrics/mAP50-95(B)': 0.2169552594396877,
#                   'fitness': 0.2169552594396877}}
#
# [Predict] start
#
# image 1/1 /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/data/images/train/0000049157P.JPG.jpg: 1088x672 1 바위, 3 모란s, 1 이름 모를 새, 3 초롱꽃s, 95.5ms
# Speed: 4.6ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1088, 672)
# Results saved to /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/runs/detect/predict2
# [JSON saved] /content/drive/MyDrive/SemioticRAG/MinhwaOD/preprocessing/KIDP_yolo_dt/artifacts/sample1_detect.json
# [Detections] 8
#
# [Preview]
# {'det_id': 1, 'class_id': 83, 'class_name': '이름 모를 새', 'confidence': 0.9769425392150879, 'bbox_xyxy': [91.29148864746094, 365.1635437011719, 310.9325256347656, 448.5294189453125]}
# {'det_id': 2, 'class_id': 11, 'class_name': '바위', 'confidence': 0.9714896082878113, 'bbox_xyxy': [0.0, 766.4092407226562, 215.0001220703125, 1024.0]}
# {'det_id': 3, 'class_id': 16, 'class_name': '모란', 'confidence': 0.9511595368385315, 'bbox_xyxy': [107.94783782958984, 448.7926330566406, 226.79006958007812, 621.4149780273438]}
# {'det_id': 4, 'class_id': 16, 'class_name': '모란', 'confidence': 0.9068211317062378, 'bbox_xyxy': [184.8373260498047, 598.3531494140625, 394.29364013671875, 756.1373291015625]}
# {'det_id': 5, 'class_id': 16, 'class_name': '모란', 'confidence': 0.9005807638168335, 'bbox_xyxy': [363.20196533203125, 531.6616821289062, 550.71337890625, 693.6951904296875]}
# {'det_id': 6, 'class_id': 202, 'class_name': '초롱꽃', 'confidence': 0.8162841200828552, 'bbox_xyxy': [0.0, 0.06460391730070114, 301.0572509765625, 184.2493438720703]}
# {'det_id': 7, 'class_id': 202, 'class_name': '초롱꽃', 'confidence': 0.6906322240829468, 'bbox_xyxy': [299.2408142089844, 24.903291702270508, 617.0, 268.9179382324219]}
# {'det_id': 8, 'class_id': 202, 'class_name': '초롱꽃', 'confidence': 0.29115819931030273, 'bbox_xyxy': [0.0, 0.40041935443878174, 300.7928466796875, 183.81275939941406]}
# wandb: ⢿ uploading artifact inference-json (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact inference-json (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact inference-json (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact inference-json (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact inference-json (0.5s)
# wandb: ⣯ uploading artifact inference-json (0.5s)
# wandb: ⣟ uploading artifact inference-json (0.5s)
# wandb: ⡿ uploading artifact inference-json (0.5s)
# wandb: ⢿ uploading artifact inference-json (0.5s)
# wandb: ⣻ uploading artifact inference-json (1.0s)
# wandb: ⣽ uploading artifact inference-json (1.0s)
# wandb: ⣾ uploading artifact inference-json (1.0s)
# wandb: ⣷ uploading artifact inference-json (1.0s)
# wandb: ⣯ uploading artifact inference-json (1.0s)
# wandb: ⣟ uploading artifact inference-json (1.5s)
# wandb: ⡿ uploading artifact inference-json (1.5s)
# wandb: ⢿ uploading artifact inference-json (1.5s)
# wandb: ⣻ uploading artifact inference-json (1.5s)
# wandb: ⣽ uploading artifact inference-json (1.5s)
# wandb: ⣾ uploading artifact inference-json (2.0s)
# wandb: ⣷ uploading artifact inference-json (2.0s)
# wandb: ⣯ uploading artifact inference-json (2.0s)
# wandb: ⣟ uploading artifact inference-json (2.0s)
# wandb: ⡿ uploading artifact inference-json (2.0s)
# wandb: ⢿ uploading artifact inference-json (2.5s)
# wandb: ⣻ uploading artifact inference-json (2.5s)
# wandb: ⣽ uploading artifact inference-json (2.5s)
# wandb: ⣾ uploading artifact inference-json (2.5s)
# wandb: ⣷ uploading artifact inference-json (2.5s)
# wandb: ⣯ uploading artifact inference-json (3.0s)
# wandb: ⣟ uploading artifact inference-json (3.0s)
# wandb: ⡿ uploading artifact inference-json (3.0s)
# wandb: ⢿ uploading artifact inference-json (3.0s)
# wandb: ⣻ uploading artifact inference-json (3.0s)
# wandb: ⣽ uploading artifact inference-json (3.5s)
# wandb:   ↳ ⣽ sample1_detect.json 2.3KB/2.3KB (0.2s)
# wandb: ⣾ uploading artifact inference-json (3.5s)
# wandb:   ↳ ⣾ sample1_detect.json 2.3KB/2.3KB (0.2s)
# wandb: ⣷ uploading artifact inference-json (3.5s)
# wandb:   ↳ ⣷ sample1_detect.json 2.3KB/2.3KB (0.2s)
# wandb: ⣯ uploading artifact inference-json (3.5s)
# wandb:   ↳ ⣯ sample1_detect.json 2.3KB/2.3KB (0.2s)
# wandb: ⣟ uploading artifact inference-json (3.5s)
# wandb:   ↳ ⣟ sample1_detect.json 2.3KB/2.3KB (0.2s)
# wandb: ⡿ uploading artifact inference-json (4.0s)
# wandb: ⢿ uploading artifact inference-json (4.0s)
# wandb: ⣻ uploading artifact inference-json (4.0s)
# wandb: ⣽ uploading artifact inference-json (4.0s)
# wandb: ⣾ uploading artifact inference-json (4.0s)
# wandb: ⣷ uploading artifact inference-json (4.5s)
# wandb: ⣯ uploading artifact inference-json (4.5s)
# wandb: ⣟ uploading artifact inference-json (4.5s)
# wandb: ⡿ uploading artifact inference-json (4.5s)
# wandb: ⢿ uploading artifact inference-json (4.5s)
# wandb: ⣻ uploading wandb-summary.json 566B/566B (0.1s)
# wandb: ⣻ uploading config.yaml 5.9KB/5.9KB (0.1s)
# wandb: ⣻ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣻ uploading output.log 71.3KB/71.3KB (0.1s)
# wandb: ⣻ uploading history steps 0-1, summary, console lines 648-751 (0.1s)
# wandb: ⣽ uploading wandb-summary.json 566B/566B (0.1s)
# wandb: ⣽ uploading config.yaml 5.9KB/5.9KB (0.1s)
# wandb: ⣽ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣽ uploading output.log 71.3KB/71.3KB (0.1s)
# wandb: ⣽ uploading history steps 0-1, summary, console lines 648-751 (0.1s)
# wandb: ⣾ uploading wandb-summary.json 566B/566B (0.1s)
# wandb: ⣾ uploading config.yaml 5.9KB/5.9KB (0.1s)
# wandb: ⣾ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣾ uploading output.log 71.3KB/71.3KB (0.1s)
# wandb: ⣾ uploading history steps 0-1, summary, console lines 648-751 (0.1s)
# wandb: ⣷ uploading wandb-summary.json 566B/566B (0.1s)
# wandb: ⣷ uploading config.yaml 5.9KB/5.9KB (0.1s)
# wandb: ⣷ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣷ uploading output.log 71.3KB/71.3KB (0.1s)
# wandb: ⣷ uploading history steps 0-1, summary, console lines 648-751 (0.1s)
# wandb: ⣯ uploading wandb-summary.json 566B/566B (0.1s)
# wandb: ⣯ uploading config.yaml 5.9KB/5.9KB (0.1s)
# wandb: ⣯ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣯ uploading output.log 71.3KB/71.3KB (0.1s)
# wandb: ⣯ uploading history steps 0-1, summary, console lines 648-751 (0.1s)
# wandb: ⣟ uploading config.yaml 5.9KB/5.9KB (0.6s)
# wandb: ⣟ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣟ uploading output.log 71.3KB/71.3KB (0.6s)
# wandb: ⡿ uploading config.yaml 5.9KB/5.9KB (0.6s)
# wandb: ⡿ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⡿ uploading output.log 71.3KB/71.3KB (0.6s)
# wandb: ⢿ uploading config.yaml 5.9KB/5.9KB (0.6s)
# wandb: ⢿ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⢿ uploading output.log 71.3KB/71.3KB (0.6s)
# wandb: ⣻ uploading config.yaml 5.9KB/5.9KB (0.6s)
# wandb: ⣻ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣻ uploading output.log 71.3KB/71.3KB (0.6s)
# wandb: ⣽ uploading config.yaml 5.9KB/5.9KB (0.6s)
# wandb: ⣽ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣽ uploading output.log 71.3KB/71.3KB (0.6s)
# wandb: ⣾ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣷ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣯ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb: ⣟ uploading media/images/inference/overlay_1_da2c7d8c5898ec61e99c.png ...
# wandb:
# wandb: Run history:
# wandb:              eval/fitness ▁
# wandb:     eval/metrics/mAP50(B) ▁
# wandb:  eval/metrics/mAP50-95(B) ▁
# wandb: eval/metrics/precision(B) ▁
# wandb:    eval/metrics/recall(B) ▁
# wandb:
# wandb: Run summary:
# wandb:              eval/fitness 0.21696
# wandb:     eval/metrics/mAP50(B) 0.28774
# wandb:  eval/metrics/mAP50-95(B) 0.21696
# wandb: eval/metrics/precision(B) 0.50881
# wandb:    eval/metrics/recall(B) 0.22191
# wandb:
# wandb: 🚀 View run colab_train_img1080_weighted at: https://wandb.ai/gist-infonet/minhwa-od/runs/moxdmgvc
# wandb: ⭐️ View project at: https://wandb.ai/gist-infonet/minhwa-od
# wandb: Synced 5 W&B file(s), 1 media file(s), 5 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260225_135448-moxdmgvc/logs

# %%
import ultralytics, wandb
print("ultralytics", ultralytics.__version__)
print("wandb", wandb.__version__)
# Out:
# ultralytics 8.4.16
# wandb 0.25.0
